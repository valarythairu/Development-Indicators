# %%
import pandas as pd

# %%
# !pip install openpyxl

import openpyxl

# %%
KE_data = pd.read_csv('data/WDICountry-Series.csv')

Ke_data = KE_data[KE_data['CountryCode'] == 'KEN']


Ke_data.to_excel('Ke_data.xlsx', index=False)

# %%
KE_Country = pd.read_csv('data/WDICountry.csv')

Ke_Country = KE_Country[KE_Country['Country Code'] == 'KEN']

Ke_Country.to_excel('Ke_Country.xlsx', index=False)

# %%
KE_datas = pd.read_csv('data/WDIData.csv')

Ke_datas = KE_datas[KE_datas['Country Name'] == 'Kenya']

Ke_datas.to_excel('Ke_datas.xlsx', index=False)

# %%
KE_Footnote = pd.read_csv('data/WDIFootNote.csv')

Ke_Footnote = KE_Footnote[KE_Footnote['CountryCode'] == 'KEN']

Ke_Footnote.to_excel('Ke_Footnote.xlsx', index=False)

# %%
KE_Time = pd.read_csv('data/WDISeries-Time.csv')

# KE_Time = KE_Time[KE_Time['CountryCode'] == 'KEN']

# KE_Time.to_excel('KE_Series-Time.xlsx', index=False)
KE_Time.head()
# Out:
#        SeriesCode    Year                                        DESCRIPTION  \
# 0     SP.UWT.TFRT  YR1990  Averages for regions/groups are based on count...
# 1  SP.REG.DTHS.ZS  YR1990  Averages for regions/groups are based on count...
# 2  SH.FPL.SATM.ZS  YR1990  Averages for regions/groups are based on count...
# 3     SP.DYN.WFRT  YR1990  Averages for regions/groups are based on count...
# 4  SH.MED.CMHW.P3  YR1990  Averages for regions/groups are based on count...
#
#    Unnamed: 3
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
KE_Series = pd.read_csv('data/WDISeries.csv')

KE_Series
# Out:
#             Series Code                                 Topic  \
# 0        AG.AGR.TRAC.NO  Environment: Agricultural production
# 1     AG.CON.FERT.PT.ZS  Environment: Agricultural production
# 2        AG.CON.FERT.ZS  Environment: Agricultural production
# 3        AG.LND.AGRI.K2                 Environment: Land use
# 4        AG.LND.AGRI.ZS                 Environment: Land use
# ...                 ...                                   ...
# 1472        VC.IDP.NWDS   Public Sector: Conflict & fragility
# 1473        VC.IDP.TOCV   Public Sector: Conflict & fragility
# 1474  VC.IHR.PSRC.FE.P5   Public Sector: Conflict & fragility
# 1475  VC.IHR.PSRC.MA.P5   Public Sector: Conflict & fragility
# 1476     VC.IHR.PSRC.P5   Public Sector: Conflict & fragility
#
#                                          Indicator Name Short definition  \
# 0                      Agricultural machinery, tractors              NaN
# ...
